# %%
import pandas as pd
data = pd.read_csv('SalaryPrediction.csv')
data
# Out:
# Wage        0
# Age         0
# Club        0
# League      0
# Nation      0
# Position    0
# Apps        0
# Caps        0
# dtype: int64

# %%
print(data)
# Out:
#             Wage  Age       Club             League Nation    Position  Apps  \
# 0     46,427,000   23        PSG  Ligue 1 Uber Eats    FRA     Forward   190
# 1     42,125,000   30        PSG  Ligue 1 Uber Eats    BRA   Midfilder   324
# 2     34,821,000   35        PSG  Ligue 1 Uber Eats    ARG     Forward   585
# 3     19,959,000   31  R. Madrid            La Liga    BEL     Forward   443
# 4     19,500,000   31    Man UFC     Premier League    ESP  Goalkeeper   480
# ...          ...  ...        ...                ...    ...         ...   ...
# 3902       3,400   19       Vigo            La Liga    ESP    Defender     0
# 3903       3,200   18  Famalicao      Primiera Liga    BRA  Goalkeeper     0
# 3904       2,900   18       Vigo            La Liga    ESP     Forward     0
# 3905       2,700   18       Vigo            La Liga    ESP    Defender     0
# 3906       1,400   18       Vigo            La Liga    ESP    Defender     0
#
#       Caps
# 0       57
# 1      119
# ...

# %%
import pandas as pd
df= pd.read_excel('SalaryPrediction.xlsx')
df.head(10)
# Out:
#        Wage  Age       Club             League Nation    Position  Apps  Caps
# 0  46427000   23        PSG  Ligue 1 Uber Eats    FRA     Forward   190    57
# 1  42125000   30        PSG  Ligue 1 Uber Eats    BRA   Midfilder   324   119
# 2  34821000   35        PSG  Ligue 1 Uber Eats    ARG     Forward   585   162
# 3  19959000   31  R. Madrid            La Liga    BEL     Forward   443   120
# 4  19500000   31    Man UFC     Premier League    ESP  Goalkeeper   480    45
# 5  18810000   30  R. Madrid            La Liga    AUT    Defender   371    94
# 6  18200000   29      Inter            Serie A    BEL     Forward   427   102
# 7  18200000   30  Liverpool     Premier League    EGY     Forward   367    85
# 8  18200000   27    Chelsea     Premier League    ENG   Midfilder   326    77
# 9  18200000   29    Man UFC     Premier League    FRA    Defender   287    86

# %%
import pandas as pd
dataFrame = pd.read_csv('SalaryPrediction.txt')
print(dataFrame)
# Out:
#             Wage  Age       Club             League Nation    Position  Apps  \
# 0     46,427,000   23        PSG  Ligue 1 Uber Eats    FRA     Forward   190
# 1     42,125,000   30        PSG  Ligue 1 Uber Eats    BRA   Midfilder   324
# 2     34,821,000   35        PSG  Ligue 1 Uber Eats    ARG     Forward   585
# 3     19,959,000   31  R. Madrid            La Liga    BEL     Forward   443
# 4     19,500,000   31    Man UFC     Premier League    ESP  Goalkeeper   480
# ...          ...  ...        ...                ...    ...         ...   ...
# 3902       3,400   19       Vigo            La Liga    ESP    Defender     0
# 3903       3,200   18  Famalicao      Primiera Liga    BRA  Goalkeeper     0
# 3904       2,900   18       Vigo            La Liga    ESP     Forward     0
# 3905       2,700   18       Vigo            La Liga    ESP    Defender     0
# 3906       1,400   18       Vigo            La Liga    ESP    Defender     0
#
#       Caps
# 0       57
# 1      119
# ...

# %%
data.columns
# Out:
# Index(['Wage', 'Age', 'Club', 'League', 'Nation', 'Position', 'Apps', 'Caps'], dtype='object')

# %%
print(data[['Club','Age','League']])
# Out:
#            Club  Age             League
# 0           PSG   23  Ligue 1 Uber Eats
# 1           PSG   30  Ligue 1 Uber Eats
# 2           PSG   35  Ligue 1 Uber Eats
# 3     R. Madrid   31            La Liga
# 4       Man UFC   31     Premier League
# ...         ...  ...                ...
# 3902       Vigo   19            La Liga
# 3903  Famalicao   18      Primiera Liga
# 3904       Vigo   18            La Liga
# 3905       Vigo   18            La Liga
# 3906       Vigo   18            La Liga
#
# [3907 rows x 3 columns]

# %%
print(data.iloc[1:4])
# Out:
#          Wage  Age       Club             League Nation   Position  Apps  Caps
# 1  42,125,000   30        PSG  Ligue 1 Uber Eats    BRA  Midfilder   324   119
# 2  34,821,000   35        PSG  Ligue 1 Uber Eats    ARG    Forward   585   162
# 3  19,959,000   31  R. Madrid            La Liga    BEL    Forward   443   120

# %%
print(data.iloc[2,1])
# Out:
# 35

# %%
data.describe()
# Out:
#                Age         Apps         Caps
# count  3907.000000  3907.000000  3907.000000
# mean     24.120553   140.057077     8.926542
# std       4.935638   131.694425    20.518234
# min      18.000000     0.000000     0.000000
# 25%      20.000000    15.000000     0.000000
# 50%      24.000000   115.000000     0.000000
# 75%      28.000000   224.500000     6.000000
# max      41.000000   715.000000   180.000000

# %%
print(data.loc[data['Club'] == 'Arsenal'])
# Out:
#            Wage  Age     Club          League Nation    Position  Apps  Caps
# 78    9,360,000   21  Arsenal  Premier League    BRA     Forward    80     3
# 104   8,320,000   29  Arsenal  Premier League    GHA   Midfilder   281    40
# 180   6,240,000   25  Arsenal  Premier League    UKR    Defender   132    52
# 181   6,240,000   23  Arsenal  Premier League    NOR   Midfilder   242    43
# 183   6,240,000   25  Arsenal  Premier League    BRA     Forward   212    56
# 197   5,720,000   27  Arsenal  Premier League    BEL    Defender   290    19
# 201   5,720,000   30  Arsenal  Premier League    ITA   Midfilder   395    44
# 202   5,720,000   25  Arsenal  Premier League    SCO    Defender   170    32
# 205   5,720,000   29  Arsenal  Premier League    SUI   Midfilder   383   104
# 237   5,200,000   24  Arsenal  Premier League    BRA    Defender   134     0
# 288   4,680,000   24  Arsenal  Premier League    ENG    Defender   177     4
# ...

# %%
data.sort_values(['Nation', 'Club'], ascending=[1,0])
# Out:
#            Wage  Age         Club             League Nation    Position  Apps  \
# 1721    567,000   30    Vallecano            La Liga    ALB    Defender   317
# 944   1,595,000   33       Torino            Serie A    ALB  Goalkeeper   279
# 1060  1,328,000   23     Sassuolo            Serie A    ALB   Midfilder   187
# 3599     21,500   19     Sassuolo            Serie A    ALB   Midfilder     0
# 2680    112,000   30      Salento            Serie A    ALB    Defender   258
# ...         ...  ...          ...                ...    ...         ...   ...
# 346   4,160,000   23    Leicester     Premier League    ZAM     Forward   138
# 3296     33,500   18     Atalanta            Serie A    ZAM   Midfilder    22
# 2137    293,000   26        Reims  Ligue 1 Uber Eats    ZIM   Midfilder   150
# 1287  1,032,000   26     Mallorca            La Liga    ZIM     Forward   162
# 1075  1,300,000   22  Bournemouth     Premier League    ZIM    Defender    42
#
#       Caps
# 1721     6
# ...

# %%
data['Total Apps'] = data['Apps'] + data['Caps']
data
# Out:
#             Wage  Age       Club             League Nation    Position  Apps  \
# 0     46,427,000   23        PSG  Ligue 1 Uber Eats    FRA     Forward   190
# 1     42,125,000   30        PSG  Ligue 1 Uber Eats    BRA   Midfilder   324
# 2     34,821,000   35        PSG  Ligue 1 Uber Eats    ARG     Forward   585
# 3     19,959,000   31  R. Madrid            La Liga    BEL     Forward   443
# 4     19,500,000   31    Man UFC     Premier League    ESP  Goalkeeper   480
# ...          ...  ...        ...                ...    ...         ...   ...
# 3902       3,400   19       Vigo            La Liga    ESP    Defender     0
# 3903       3,200   18  Famalicao      Primiera Liga    BRA  Goalkeeper     0
# 3904       2,900   18       Vigo            La Liga    ESP     Forward     0
# 3905       2,700   18       Vigo            La Liga    ESP    Defender     0
# 3906       1,400   18       Vigo            La Liga    ESP    Defender     0
#
#       Caps  Total Apps
# ...

# %%
new_data =data[['Club', 'League', 'Nation', 'Position', 'Wage', 'Age','Apps', 'Caps','Total Apps']]
new_data.to_csv('Modified.csv')

# %%
new_data.to_excel('Modified.xlsx' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 new_data.to_excel('Modified.xlsx' )
#
# NameError: name 'new_data' is not defined

# %%
new_data.to_csv('Modified.txt', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 new_data.to_csv('Modified.txt', sep='\t')
#
# NameError: name 'new_data' is not defined

# %%
dt= data.loc[(data['Club'] == 'PSG')   & (data['Age'] >= 20)]
dt.reset_index(drop=True, inplace=True)
dt
# Out:
#           Wage  Age Club             League Nation    Position  Apps  Caps
# 0   46,427,000   23  PSG  Ligue 1 Uber Eats    FRA     Forward   190    57
# 1   42,125,000   30  PSG  Ligue 1 Uber Eats    BRA   Midfilder   324   119
# 2   34,821,000   35  PSG  Ligue 1 Uber Eats    ARG     Forward   585   162
# 3   12,381,000   29  PSG  Ligue 1 Uber Eats    ITA   Midfilder   327    49
# 4   12,381,000   28  PSG  Ligue 1 Uber Eats    BRA    Defender   273    69
# 5   11,710,000   36  PSG  Ligue 1 Uber Eats    ESP    Defender   547   180
# 6   11,177,000   23  PSG  Ligue 1 Uber Eats    ITA  Goalkeeper   239    46
# 7    8,924,000   23  PSG  Ligue 1 Uber Eats    MAR    Defender   167    51
# 8    8,598,000   27  PSG  Ligue 1 Uber Eats    FRA    Defender   159    28
# 9    7,222,000   29  PSG  Ligue 1 Uber Eats    ESP    Defender   212    11
# 10   4,594,000   25  PSG  Ligue 1 Uber Eats    ESP    Defender   222     9
# ...

# %%
dt.loc[dt['Position'].str.contains('er')]
# Out:
#           Wage  Age Club             League Nation    Position  Apps  Caps
# 1   42,125,000   30  PSG  Ligue 1 Uber Eats    BRA   Midfilder   324   119
# 3   12,381,000   29  PSG  Ligue 1 Uber Eats    ITA   Midfilder   327    49
# 4   12,381,000   28  PSG  Ligue 1 Uber Eats    BRA    Defender   273    69
# 5   11,710,000   36  PSG  Ligue 1 Uber Eats    ESP    Defender   547   180
# 6   11,177,000   23  PSG  Ligue 1 Uber Eats    ITA  Goalkeeper   239    46
# 7    8,924,000   23  PSG  Ligue 1 Uber Eats    MAR    Defender   167    51
# 8    8,598,000   27  PSG  Ligue 1 Uber Eats    FRA    Defender   159    28
# 9    7,222,000   29  PSG  Ligue 1 Uber Eats    ESP    Defender   212    11
# 10   4,594,000   25  PSG  Ligue 1 Uber Eats    ESP    Defender   222     9
# 11   4,091,000   22  PSG  Ligue 1 Uber Eats    POR   Midfilder    78     3
# 12   3,869,000   30  PSG  Ligue 1 Uber Eats    POR    Defender   294    61
# ...

# %%
import re
dt.loc[dt['Nation'].str.contains('a|p', flags=re.I)]
# Out:
#           Wage  Age Club             League Nation    Position  Apps  Caps
# 0   46,427,000   23  PSG  Ligue 1 Uber Eats    FRA     Forward   190    57
# 1   42,125,000   30  PSG  Ligue 1 Uber Eats    BRA   Midfilder   324   119
# 2   34,821,000   35  PSG  Ligue 1 Uber Eats    ARG     Forward   585   162
# 3   12,381,000   29  PSG  Ligue 1 Uber Eats    ITA   Midfilder   327    49
# 4   12,381,000   28  PSG  Ligue 1 Uber Eats    BRA    Defender   273    69
# 5   11,710,000   36  PSG  Ligue 1 Uber Eats    ESP    Defender   547   180
# 6   11,177,000   23  PSG  Ligue 1 Uber Eats    ITA  Goalkeeper   239    46
# 7    8,924,000   23  PSG  Ligue 1 Uber Eats    MAR    Defender   167    51
# 8    8,598,000   27  PSG  Ligue 1 Uber Eats    FRA    Defender   159    28
# 9    7,222,000   29  PSG  Ligue 1 Uber Eats    ESP    Defender   212    11
# 10   4,594,000   25  PSG  Ligue 1 Uber Eats    ESP    Defender   222     9
# ...

# %%
import re
dt.loc[dt['Nation'].str.contains('a|o',flags=re.I, regex=True)]
# Out:
#           Wage  Age Club             League Nation    Position  Apps  Caps
# 0   46,427,000   23  PSG  Ligue 1 Uber Eats    FRA     Forward   190    57
# 1   42,125,000   30  PSG  Ligue 1 Uber Eats    BRA   Midfilder   324   119
# 2   34,821,000   35  PSG  Ligue 1 Uber Eats    ARG     Forward   585   162
# 3   12,381,000   29  PSG  Ligue 1 Uber Eats    ITA   Midfilder   327    49
# 4   12,381,000   28  PSG  Ligue 1 Uber Eats    BRA    Defender   273    69
# 6   11,177,000   23  PSG  Ligue 1 Uber Eats    ITA  Goalkeeper   239    46
# 7    8,924,000   23  PSG  Ligue 1 Uber Eats    MAR    Defender   167    51
# 8    8,598,000   27  PSG  Ligue 1 Uber Eats    FRA    Defender   159    28
# 11   4,091,000   22  PSG  Ligue 1 Uber Eats    POR   Midfilder    78     3
# 12   3,869,000   30  PSG  Ligue 1 Uber Eats    POR    Defender   294    61
# 13   3,476,000   25  PSG  Ligue 1 Uber Eats    POR   Midfilder   177    32
# ...

# %%
dt.loc[dt['Total Apps'] > 350, ['Position']] = 'LEGEND'
dt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Apps'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 arr = np.arrange(12)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'
